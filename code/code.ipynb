# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %%
cities
# Out:
# ['yirol',
#  'galesong',
#  'malanje',
#  'saskylakh',
#  'busselton',
#  'broken hill',
#  'oktyabrskoye',
#  'abu dhabi',
#  'kodiak',
#  'antigonish',
#  'port elizabeth',
#  'talnakh',
#  'belushya guba',
#  'hilo',
#  'turbiv',
#  'kihei',
#  'alofi',
#  'bundaberg',
#  'bontang',
#  'yomitan',
#  'punta arenas',
#  'sao joao da barra',
#  'adrar',
#  'vaini',
#  'jamestown',
#  'itarema',
#  'cape town',
#  'albany',
#  'san jose',
#  'arraial do cabo',
#  'tsihombe',
#  'kagoro',
#  'ushuaia',
#  'mwense',
#  'teguldet',
#  'xichang',
#  'kununurra',
#  'lorengau',
#  'barentsburg',
#  'thompson',
#  'inhambane',
#  'avarua',
#  'xining',
#  'fremont',
#  'east london',
#  'srednekolymsk',
#  'codrington',
#  'evensk',
#  'nanyang',
#  'mataura',
#  'attawapiskat',
#  'kapaa',
#  'rikitea',
#  'anloga',
#  'paamiut',
#  'vila velha',
#  'mahebourg',
#  'zaplyusye',
#  'chokurdakh',
#  'muskegon',
#  'port alfred',
#  'daru',
#  'kiruna',
#  'nizhneyansk',
#  'charters towers',
#  'puerto ayora',
#  'radford',
#  'bredasdorp',
#  'nyurba',
#  'tasiilaq',
#  'severo-kurilsk',
#  'luganville',
#  'hobyo',
#  'high prairie',
#  'salalah',
#  'road town',
#  'nokaneng',
#  'tabiauea',
#  'cockburn town',
#  'bo rai',
#  'pundaguitan',
#  'taolanaro',
#  'wa',
#  'bengkulu',
#  'neiafu',
#  'pisco',
#  'ranong',
#  'jurm',
#  'butaritari',
#  'kavieng',
#  'sembakung',
#  'kavaratti',
#  'newport',
#  'verkhoyansk',
#  'worthington',
#  'touros',
#  'borama',
#  'marcona',
#  'kirakira',
#  'general roca',
#  'bilibino',
#  'maniitsoq',
#  'haines junction',
#  'tuktoyaktuk',
#  'hithadhoo',
#  'palmer',
#  'carnarvon',
#  'tessalit',
#  'meyungs',
#  'barrow',
#  'qaanaaq',
#  'hasaki',
#  'hobart',
#  'upernavik',
#  'richards bay',
#  'vermilion',
#  'brazzaville',
#  'lokosovo',
#  'saldanha',
#  'mar del plata',
#  'chuy',
#  'tayoltita',
#  'jiwani',
#  'torbay',
#  'atuona',
#  'san patricio',
#  'bethel',
#  'fantino',
#  'bluff',
#  'tilichiki',
#  'abashiri',
#  'lebu',
#  'saint-philippe',
#  'pevek',
#  'sokur',
#  'lamu',
#  'cidreira',
#  'ponta do sol',
#  'yizheng',
#  'yellowknife',
#  'tateyama',
#  'narsaq',
#  'nioro',
#  'iqaluit',
#  'mazamari',
#  'isangel',
#  'namatanai',
#  'plettenberg bay',
#  'rawson',
#  'moree',
#  'norton',
#  'zhezkazgan',
#  'halalo',
#  'ankang',
#  'the valley',
#  'san cristobal',
#  'buin',
#  'sinnamary',
#  'port hardy',
#  'cairo',
#  'quatre cocos',
#  'tumannyy',
#  'mananjary',
#  'kolokani',
#  'kaitangata',
#  'laguna',
#  'fairbanks',
#  'port blair',
#  'monrovia',
#  'taburao',
#  'dhidhdhoo',
#  'pemba',
#  'samusu',
#  'muros',
#  'rodrigues alves',
#  'taltal',
#  'castro',
#  'dunmore town',
#  'new norfolk',
#  'san quintin',
#  'kruisfontein',
#  'amderma',
#  'moron',
#  'coro',
#  'khatanga',
#  'ilulissat',
#  'provideniya',
#  'mizan teferi',
#  'tubruq',
#  'derzhavinsk',
#  'seoul',
#  'jega',
#  'esperance',
#  'malinovskiy',
#  'benguela',
#  'kankan',
#  'fortuna',
#  'georgetown',
#  'dzhida',
#  'bikaner',
#  'hermanus',
#  'norman wells',
#  'avezzano',
#  'lityn',
#  'acapulco',
#  'ilinskiy',
#  'longyearbyen',
#  'sumter',
#  'bambous virieux',
#  'sidney',
#  'korla',
#  'marsaxlokk',
#  'hualmay',
#  'medea',
#  'nanortalik',
#  'saint-augustin',
#  'iralaya',
#  'amahai',
#  'bhatkal',
#  'tawkar',
#  'markova',
#  'guerrero negro',
#  'bay city',
#  'merauke',
#  'chiredzi',
#  'xinqing',
#  'lavrentiya',
#  'maragogi',
#  'takaka',
#  'nemuro',
#  'veraval',
#  'sinkat',
#  'clyde river',
#  'ust-maya',
#  'varhaug',
#  'tecoanapa',
#  'tara',
#  'coihaique',
#  'dingle',
#  'beringovskiy',
#  'eureka',
#  'lompoc',
#  'mys shmidta',
#  'illoqqortoormiut',
#  'vestmannaeyjar',
#  'sri aman',
#  'linden',
#  'gat',
#  'lukovetskiy',
#  'roros',
#  'portland',
#  'jadu',
#  'meulaboh',
#  'lithakia',
#  'rocha',
#  'baruun-urt',
#  'dawson creek',
#  'magistralnyy',
#  'olafsvik',
#  'maghama',
#  'saint-louis',
#  'constitucion',
#  'khovu-aksy',
#  'hovd',
#  'ambatofinandrahana',
#  'ngunguru',
#  'chapais',
#  'jimo',
#  'umzimvubu',
#  'saint george',
#  'victoria',
#  'cayenne',
#  'russell',
#  'guaymas',
#  'manjacaze',
#  'katsuura',
#  'airai',
#  'bahia blanca',
#  'bonthe',
#  'terrace bay',
#  'susuman',
#  'leningradskiy',
#  'karasburg',
#  'turek',
#  'cherskiy',
#  'birecik',
#  'sosnovka',
#  'balagansk',
#  'labuhan',
#  'crab hill',
#  'lata',
#  'vikhorevka',
#  'zyryanka',
#  'sao filipe',
#  'raudeberg',
#  'sisophon',
#  'caravelas',
#  'cabo san lucas',
#  'havre-saint-pierre',
#  'nikolskoye',
#  'alakurtti',
#  'port lincoln',
#  'pangoa',
#  'inuvik',
#  'aasiaat',
#  'roald',
#  'santa rosa',
#  'arlit',
#  'bud',
#  'balkhash',
#  'flinders',
#  'ust-tsilma',
#  'tabialan',
#  'suchdol nad luznici',
#  'sataua',
#  'mehamn',
#  'yeniseysk',
#  'ahipara',
#  'quelimane',
#  'presidencia roque saenz pena',
#  'lamar',
#  'mandurah',
#  'broome',
#  'shuangyang',
#  'ekibastuz',
#  'nantucket',
#  'manoharpur',
#  'stromness',
#  'kuytun',
#  'kenai',
#  'srandakan',
#  'mogadishu',
#  'nipawin',
#  'skjervoy',
#  'tiksi',
#  'the pas',
#  'pombas',
#  'dikson',
#  'magalia',
#  'nieuw amsterdam',
#  'smila',
#  'tangier',
#  'aklavik',
#  'jalu',
#  'am timan',
#  'sorland',
#  'forbes',
#  'louisbourg',
#  'langenfeld',
#  'dzaoudzi',
#  'coari',
#  'silver city',
#  'yulara',
#  'kleck',
#  'saint-georges',
#  'riberalta',
#  'waipawa',
#  'bang rakam',
#  'camacha',
#  'ajaccio',
#  'maldonado',
#  'cacoal',
#  'seymchan',
#  'temple',
#  'mahuta',
#  'katobu',
#  'roma',
#  'bato',
#  'umm lajj',
#  'naze',
#  'huarmey',
#  'vila franca do campo',
#  'yakima',
#  'kantabanji',
#  'asau',
#  'homer',
#  'shimoda',
#  'sisimiut',
#  'shimanovsk',
#  'poum',
#  'saint-francois',
#  'ciudad valles',
#  'grand river south east',
#  'prince rupert',
#  'ixtapa',
#  'hohhot',
#  'mount gambier',
#  'vardo',
#  'mazagao',
#  'kieta',
#  'vostok',
#  'balkanabat',
#  'aswan',
#  'goya',
#  'gazni',
#  'yarada',
#  'ribeira grande',
#  'adigeni',
#  'port moresby',
#  'sambava',
#  'panama city',
#  'ballina',
#  'estelle',
#  'huilong',
#  'petropavlovsk-kamchatskiy',
#  'westport',
#  'ekhabi',
#  'salisbury',
#  'phonhong',
#  'galdar',
#  'tahoua',
#  'neuquen',
#  'granadilla de abona',
#  'sistranda',
#  'ariquemes',
#  'kloulklubed',
#  'iquitos',
#  'dalbandin',
#  'ust-kuyga',
#  'carballo',
#  'berdigestyakh',
#  'nelson bay',
#  'kalaleh',
#  'tuatapere',
#  'barra do garcas',
#  'karatau',
#  'omsukchan',
#  'floro',
#  'polunochnoye',
#  'klaksvik',
#  'ambilobe',
#  'saryshagan',
#  'barsovo',
#  'kasama',
#  'tuy hoa',
#  'okhotsk',
#  'jeremie',
#  'monforte de lemos',
#  'hamilton',
#  'bayir',
#  'ostrovnoy',
#  'dzhankoy',
#  'warragul',
#  'ancud',
#  'mandan',
#  'coahuayana',
#  'chernyshevskiy',
#  'nanlong',
#  'batemans bay',
#  'atambua',
#  'lincoln',
#  'victoria point',
#  'goderich',
#  'graaff-reinet',
#  'mrirt',
#  'nova olimpia',
#  'padilla',
#  'macklin',
#  'tawang',
#  'medzilaborce',
#  'lewistown',
#  'caldwell',
#  'dourbali',
#  'progreso',
#  'ankazoabo',
#  'vega de alatorre',
#  'hambantota',
#  'champasak',
#  'bilma',
#  'kushmurun',
#  'casper',
#  'nizhniy odes',
#  'ziniare',
#  'nome',
#  'aktas',
#  'canavieiras',
#  'jiddah',
#  'christchurch',
#  'dongsheng',
#  'harper',
#  'saint-pierre',
#  'rio grande',
#  'henties bay',
#  'hanzhong',
#  'stutterheim',
#  'limon',
#  'ano mera',
#  'hokitika',
#  'navrongo',
#  'makakilo city',
#  'aviles',
#  'cehegin',
#  'dunedin',
#  'carutapera',
#  'sobolevo',
#  'jumla',
#  'sao felix do xingu',
#  'almeirim',
#  'jiazi',
#  'tongren',
#  'linxia',
#  'balakhta',
#  'husavik',
#  'zelenets',
#  'maloy',
#  'wewak',
#  'puerto del rosario',
#  'pangnirtung',
#  'souillac',
#  'bandarbeyla',
#  'college',
#  'bathsheba',
#  'morondava',
#  'denpasar',
#  'kahama',
#  'hofn',
#  'chlorakas',
#  'lolua',
#  'georgiyevka',
#  'ferrol',
#  'san francisco',
#  'viedma',
#  'beaumont',
#  'winchester',
#  'ksenyevka',
#  'abu samrah',
#  'itamaraju',
#  'yumen',
#  'phan thiet',
#  'belyy yar',
#  'rybinsk',
#  'wembley',
#  'valparaiso',
#  'beloha',
#  'ponerihouen',
#  'byron bay',
#  'lethem',
#  'itinga',
#  'natal',
#  'sarakhs',
#  'toliary',
#  'mumford',
#  'alta',
#  'ewa beach',
#  'ketchikan',
#  'zharkent',
#  'walvis bay',
#  'catamarca',
#  'cimarron hills',
#  'komsomolskiy',
#  'tacuati',
#  'moindou',
#  'ghatsila',
#  'dovers',
#  'el dorado',
#  'margate',
#  'tabuk',
#  'mayna',
#  'sentyabrskiy',
#  'shirokiy',
#  'digby',
#  'karauzyak',
#  'junction city',
#  'gualeguay',
#  'pacific grove',
#  'japura',
#  'shakawe',
#  'candolim',
#  'igarka',
#  'mackay',
#  'aqtobe',
#  'dunmore east',
#  'ous',
#  'port augusta',
#  'sumbe',
#  'sorada',
#  'paducah',
#  'kota tinggi',
#  'viligili',
#  'tyup',
#  'la paz',
#  'bahia honda',
#  'port-cartier',
#  'sorong',
#  'mitsamiouli',
#  'talcahuano',
#  'vaitupu',
#  'gornyak',
#  'alizai',
#  'finschhafen',
#  'san carlos de bariloche',
#  'chabahar',
#  'caramay',
#  'manta',
#  'kamenka',
#  'breytovo',
#  'galiakot',
#  'palabuhanratu',
#  'bezhanitsy',
#  'port macquarie',
#  'milingimbi',
#  'iranshahr',
#  'sibolga',
#  'ocosingo',
#  'lucea',
#  'starosubkhangulovo']

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# Sort Data
city_final = []
cloud = []
lat = []
lng = []
temp_max = []
country = []
date = []
humid = []
wind = []
counter = 0


#API Measures for 60 request per minute max issues
time.sleep(61)

for city in cities:
    try:
        response = requests.get(query_url + city).json()
    except:
        time.sleep(61)
    if response['cod'] != "404":
        counter += 1
        print(f"Processing Record {counter} of Set 1| {city}")
        city_final.append(city.title())
        cloud.append(response['clouds']['all'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp_max.append(response['main']['temp_max'])
        country.append(response["sys"]["country"])
        date.append(response['dt'])
        humid.append(response['main']["humidity"])
        wind.append(response['wind']["speed"])
        time.sleep(1)
    else:
        print("City not found. Skipping...")
        time.sleep(1) 


weather_dict = {
    "City": city_final,
    "Country": country,
    "Date": date,
    "Lng": lng,
    "Lat": lat,
    "Max Temp": temp_max,
    "Cloudiness": cloud, 
    "Humidity": humid,
    "Wind Speed": wind
}
# Out:
# City not found. Skipping...
# Processing Record 1 of Set 1| galesong
# Processing Record 2 of Set 1| malanje
# Processing Record 3 of Set 1| saskylakh
# Processing Record 4 of Set 1| busselton
# Processing Record 5 of Set 1| broken hill
# Processing Record 6 of Set 1| oktyabrskoye
# Processing Record 7 of Set 1| abu dhabi
# Processing Record 8 of Set 1| kodiak
# Processing Record 9 of Set 1| antigonish
# Processing Record 10 of Set 1| port elizabeth
# Processing Record 11 of Set 1| talnakh
# City not found. Skipping...
# Processing Record 12 of Set 1| hilo
# Processing Record 13 of Set 1| turbiv
# Processing Record 14 of Set 1| kihei
# Processing Record 15 of Set 1| alofi
# Processing Record 16 of Set 1| bundaberg
# Processing Record 17 of Set 1| bontang
# City not found. Skipping...
# Processing Record 18 of Set 1| punta arenas
# Processing Record 19 of Set 1| sao joao da barra
# Processing Record 20 of Set 1| adrar
# Processing Record 21 of Set 1| vaini
# Processing Record 22 of Set 1| jamestown
# Processing Record 23 of Set 1| itarema
# Processing Record 24 of Set 1| cape town
# Processing Record 25 of Set 1| albany
# Processing Record 26 of Set 1| san jose
# Processing Record 27 of Set 1| arraial do cabo
# City not found. Skipping...
# Processing Record 28 of Set 1| kagoro
# Processing Record 29 of Set 1| ushuaia
# Processing Record 30 of Set 1| mwense
# Processing Record 31 of Set 1| teguldet
# Processing Record 32 of Set 1| xichang
# Processing Record 33 of Set 1| kununurra
# Processing Record 34 of Set 1| lorengau
# City not found. Skipping...
# Processing Record 35 of Set 1| thompson
# Processing Record 36 of Set 1| inhambane
# Processing Record 37 of Set 1| avarua
# Processing Record 38 of Set 1| xining
# Processing Record 39 of Set 1| fremont
# Processing Record 40 of Set 1| east london
# Processing Record 41 of Set 1| srednekolymsk
# Processing Record 42 of Set 1| codrington
# Processing Record 43 of Set 1| evensk
# Processing Record 44 of Set 1| nanyang
# Processing Record 45 of Set 1| mataura
# City not found. Skipping...
# Processing Record 46 of Set 1| kapaa
# Processing Record 47 of Set 1| rikitea
# Processing Record 48 of Set 1| anloga
# Processing Record 49 of Set 1| paamiut
# Processing Record 50 of Set 1| vila velha
# Processing Record 51 of Set 1| mahebourg
# City not found. Skipping...
# Processing Record 52 of Set 1| chokurdakh
# Processing Record 53 of Set 1| muskegon
# Processing Record 54 of Set 1| port alfred
# Processing Record 55 of Set 1| daru
# Processing Record 56 of Set 1| kiruna
# City not found. Skipping...
# Processing Record 57 of Set 1| charters towers
# Processing Record 58 of Set 1| puerto ayora
# Processing Record 59 of Set 1| radford
# Processing Record 60 of Set 1| bredasdorp
# Processing Record 61 of Set 1| nyurba
# Processing Record 62 of Set 1| tasiilaq
# Processing Record 63 of Set 1| severo-kurilsk
# Processing Record 64 of Set 1| luganville
# Processing Record 65 of Set 1| hobyo
# Processing Record 66 of Set 1| high prairie
# Processing Record 67 of Set 1| salalah
# Processing Record 68 of Set 1| road town
# Processing Record 69 of Set 1| nokaneng
# City not found. Skipping...
# Processing Record 70 of Set 1| cockburn town
# Processing Record 71 of Set 1| bo rai
# Processing Record 72 of Set 1| pundaguitan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 73 of Set 1| bengkulu
# Processing Record 74 of Set 1| neiafu
# Processing Record 75 of Set 1| pisco
# Processing Record 76 of Set 1| ranong
# Processing Record 77 of Set 1| jurm
# Processing Record 78 of Set 1| butaritari
# Processing Record 79 of Set 1| kavieng
# Processing Record 80 of Set 1| sembakung
# Processing Record 81 of Set 1| kavaratti
# Processing Record 82 of Set 1| newport
# Processing Record 83 of Set 1| verkhoyansk
# Processing Record 84 of Set 1| worthington
# Processing Record 85 of Set 1| touros
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 86 of Set 1| kirakira
# Processing Record 87 of Set 1| general roca
# Processing Record 88 of Set 1| bilibino
# Processing Record 89 of Set 1| maniitsoq
# Processing Record 90 of Set 1| haines junction
# Processing Record 91 of Set 1| tuktoyaktuk
# Processing Record 92 of Set 1| hithadhoo
# Processing Record 93 of Set 1| palmer
# Processing Record 94 of Set 1| carnarvon
# Processing Record 95 of Set 1| tessalit
# City not found. Skipping...
# Processing Record 96 of Set 1| barrow
# Processing Record 97 of Set 1| qaanaaq
# Processing Record 98 of Set 1| hasaki
# Processing Record 99 of Set 1| hobart
# Processing Record 100 of Set 1| upernavik
# Processing Record 101 of Set 1| richards bay
# Processing Record 102 of Set 1| vermilion
# Processing Record 103 of Set 1| brazzaville
# Processing Record 104 of Set 1| lokosovo
# Processing Record 105 of Set 1| saldanha
# Processing Record 106 of Set 1| mar del plata
# Processing Record 107 of Set 1| chuy
# Processing Record 108 of Set 1| tayoltita
# Processing Record 109 of Set 1| jiwani
# Processing Record 110 of Set 1| torbay
# Processing Record 111 of Set 1| atuona
# Processing Record 112 of Set 1| san patricio
# Processing Record 113 of Set 1| bethel
# Processing Record 114 of Set 1| fantino
# Processing Record 115 of Set 1| bluff
# Processing Record 116 of Set 1| tilichiki
# Processing Record 117 of Set 1| abashiri
# Processing Record 118 of Set 1| lebu
# Processing Record 119 of Set 1| saint-philippe
# Processing Record 120 of Set 1| pevek
# Processing Record 121 of Set 1| sokur
# Processing Record 122 of Set 1| lamu
# Processing Record 123 of Set 1| cidreira
# Processing Record 124 of Set 1| ponta do sol
# Processing Record 125 of Set 1| yizheng
# Processing Record 126 of Set 1| yellowknife
# Processing Record 127 of Set 1| tateyama
# Processing Record 128 of Set 1| narsaq
# Processing Record 129 of Set 1| nioro
# Processing Record 130 of Set 1| iqaluit
# Processing Record 131 of Set 1| mazamari
# Processing Record 132 of Set 1| isangel
# Processing Record 133 of Set 1| namatanai
# Processing Record 134 of Set 1| plettenberg bay
# Processing Record 135 of Set 1| rawson
# Processing Record 136 of Set 1| moree
# Processing Record 137 of Set 1| norton
# Processing Record 138 of Set 1| zhezkazgan
# City not found. Skipping...
# Processing Record 139 of Set 1| ankang
# Processing Record 140 of Set 1| the valley
# Processing Record 141 of Set 1| san cristobal
# Processing Record 142 of Set 1| buin
# Processing Record 143 of Set 1| sinnamary
# Processing Record 144 of Set 1| port hardy
# Processing Record 145 of Set 1| cairo
# Processing Record 146 of Set 1| quatre cocos
# City not found. Skipping...
# Processing Record 147 of Set 1| mananjary
# Processing Record 148 of Set 1| kolokani
# Processing Record 149 of Set 1| kaitangata
# Processing Record 150 of Set 1| laguna
# Processing Record 151 of Set 1| fairbanks
# Processing Record 152 of Set 1| port blair
# Processing Record 153 of Set 1| monrovia
# City not found. Skipping...
# Processing Record 154 of Set 1| dhidhdhoo
# Processing Record 155 of Set 1| pemba
# City not found. Skipping...
# Processing Record 156 of Set 1| muros
# Processing Record 157 of Set 1| rodrigues alves
# Processing Record 158 of Set 1| taltal
# Processing Record 159 of Set 1| castro
# Processing Record 160 of Set 1| dunmore town
# Processing Record 161 of Set 1| new norfolk
# Processing Record 162 of Set 1| san quintin
# Processing Record 163 of Set 1| kruisfontein
# City not found. Skipping...
# Processing Record 164 of Set 1| moron
# Processing Record 165 of Set 1| coro
# Processing Record 166 of Set 1| khatanga
# Processing Record 167 of Set 1| ilulissat
# Processing Record 168 of Set 1| provideniya
# Processing Record 169 of Set 1| mizan teferi
# City not found. Skipping...
# Processing Record 170 of Set 1| derzhavinsk
# Processing Record 171 of Set 1| seoul
# Processing Record 172 of Set 1| jega
# Processing Record 173 of Set 1| esperance
# Processing Record 174 of Set 1| malinovskiy
# Processing Record 175 of Set 1| benguela
# Processing Record 176 of Set 1| kankan
# Processing Record 177 of Set 1| fortuna
# Processing Record 178 of Set 1| georgetown
# Processing Record 179 of Set 1| dzhida
# Processing Record 180 of Set 1| bikaner
# Processing Record 181 of Set 1| hermanus
# Processing Record 182 of Set 1| norman wells
# Processing Record 183 of Set 1| avezzano
# Processing Record 184 of Set 1| lityn
# Processing Record 185 of Set 1| acapulco
# Processing Record 186 of Set 1| ilinskiy
# Processing Record 187 of Set 1| longyearbyen
# Processing Record 188 of Set 1| sumter
# Processing Record 189 of Set 1| bambous virieux
# Processing Record 190 of Set 1| sidney
# Processing Record 191 of Set 1| korla
# Processing Record 192 of Set 1| marsaxlokk
# Processing Record 193 of Set 1| hualmay
# Processing Record 194 of Set 1| medea
# Processing Record 195 of Set 1| nanortalik
# Processing Record 196 of Set 1| saint-augustin
# Processing Record 197 of Set 1| iralaya
# Processing Record 198 of Set 1| amahai
# Processing Record 199 of Set 1| bhatkal
# City not found. Skipping...
# Processing Record 200 of Set 1| markova
# Processing Record 201 of Set 1| guerrero negro
# Processing Record 202 of Set 1| bay city
# Processing Record 203 of Set 1| merauke
# Processing Record 204 of Set 1| chiredzi
# Processing Record 205 of Set 1| xinqing
# Processing Record 206 of Set 1| lavrentiya
# Processing Record 207 of Set 1| maragogi
# Processing Record 208 of Set 1| takaka
# Processing Record 209 of Set 1| nemuro
# Processing Record 210 of Set 1| veraval
# City not found. Skipping...
# Processing Record 211 of Set 1| clyde river
# Processing Record 212 of Set 1| ust-maya
# Processing Record 213 of Set 1| varhaug
# Processing Record 214 of Set 1| tecoanapa
# Processing Record 215 of Set 1| tara
# Processing Record 216 of Set 1| coihaique
# Processing Record 217 of Set 1| dingle
# Processing Record 218 of Set 1| beringovskiy
# Processing Record 219 of Set 1| eureka
# Processing Record 220 of Set 1| lompoc
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 221 of Set 1| vestmannaeyjar
# Processing Record 222 of Set 1| sri aman
# Processing Record 223 of Set 1| linden
# Processing Record 224 of Set 1| gat
# Processing Record 225 of Set 1| lukovetskiy
# Processing Record 226 of Set 1| roros
# Processing Record 227 of Set 1| portland
# Processing Record 228 of Set 1| jadu
# Processing Record 229 of Set 1| meulaboh
# Processing Record 230 of Set 1| lithakia
# Processing Record 231 of Set 1| rocha
# Processing Record 232 of Set 1| baruun-urt
# Processing Record 233 of Set 1| dawson creek
# Processing Record 234 of Set 1| magistralnyy
# Processing Record 235 of Set 1| olafsvik
# City not found. Skipping...
# Processing Record 236 of Set 1| saint-louis
# Processing Record 237 of Set 1| constitucion
# Processing Record 238 of Set 1| khovu-aksy
# Processing Record 239 of Set 1| hovd
# Processing Record 240 of Set 1| ambatofinandrahana
# Processing Record 241 of Set 1| ngunguru
# Processing Record 242 of Set 1| chapais
# Processing Record 243 of Set 1| jimo
# City not found. Skipping...
# Processing Record 244 of Set 1| saint george
# Processing Record 245 of Set 1| victoria
# Processing Record 246 of Set 1| cayenne
# Processing Record 247 of Set 1| russell
# Processing Record 248 of Set 1| guaymas
# Processing Record 249 of Set 1| manjacaze
# Processing Record 250 of Set 1| katsuura
# Processing Record 251 of Set 1| airai
# Processing Record 252 of Set 1| bahia blanca
# Processing Record 253 of Set 1| bonthe
# Processing Record 254 of Set 1| terrace bay
# Processing Record 255 of Set 1| susuman
# Processing Record 256 of Set 1| leningradskiy
# Processing Record 257 of Set 1| karasburg
# Processing Record 258 of Set 1| turek
# Processing Record 259 of Set 1| cherskiy
# Processing Record 260 of Set 1| birecik
# Processing Record 261 of Set 1| sosnovka
# Processing Record 262 of Set 1| balagansk
# Processing Record 263 of Set 1| labuhan
# City not found. Skipping...
# Processing Record 264 of Set 1| lata
# Processing Record 265 of Set 1| vikhorevka
# Processing Record 266 of Set 1| zyryanka
# Processing Record 267 of Set 1| sao filipe
# Processing Record 268 of Set 1| raudeberg
# Processing Record 269 of Set 1| sisophon
# Processing Record 270 of Set 1| caravelas
# Processing Record 271 of Set 1| cabo san lucas
# Processing Record 272 of Set 1| havre-saint-pierre
# Processing Record 273 of Set 1| nikolskoye
# Processing Record 274 of Set 1| alakurtti
# Processing Record 275 of Set 1| port lincoln
# Processing Record 276 of Set 1| pangoa
# Processing Record 277 of Set 1| inuvik
# Processing Record 278 of Set 1| aasiaat
# Processing Record 279 of Set 1| roald
# Processing Record 280 of Set 1| santa rosa
# Processing Record 281 of Set 1| arlit
# Processing Record 282 of Set 1| bud
# Processing Record 283 of Set 1| balkhash
# Processing Record 284 of Set 1| flinders
# Processing Record 285 of Set 1| ust-tsilma
# City not found. Skipping...
# Processing Record 286 of Set 1| suchdol nad luznici
# City not found. Skipping...
# Processing Record 287 of Set 1| mehamn
# Processing Record 288 of Set 1| yeniseysk
# Processing Record 289 of Set 1| ahipara
# Processing Record 290 of Set 1| quelimane
# Processing Record 291 of Set 1| presidencia roque saenz pena
# Processing Record 292 of Set 1| lamar
# Processing Record 293 of Set 1| mandurah
# Processing Record 294 of Set 1| broome
# Processing Record 295 of Set 1| shuangyang
# Processing Record 296 of Set 1| ekibastuz
# Processing Record 297 of Set 1| nantucket
# Processing Record 298 of Set 1| manoharpur
# Processing Record 299 of Set 1| stromness
# Processing Record 300 of Set 1| kuytun
# Processing Record 301 of Set 1| kenai
# Processing Record 302 of Set 1| srandakan
# Processing Record 303 of Set 1| mogadishu
# Processing Record 304 of Set 1| nipawin
# Processing Record 305 of Set 1| skjervoy
# Processing Record 306 of Set 1| tiksi
# Processing Record 307 of Set 1| the pas
# Processing Record 308 of Set 1| pombas
# Processing Record 309 of Set 1| dikson
# Processing Record 310 of Set 1| magalia
# Processing Record 311 of Set 1| nieuw amsterdam
# Processing Record 312 of Set 1| smila
# Processing Record 313 of Set 1| tangier
# Processing Record 314 of Set 1| aklavik
# Processing Record 315 of Set 1| jalu
# Processing Record 316 of Set 1| am timan
# Processing Record 317 of Set 1| sorland
# Processing Record 318 of Set 1| forbes
# City not found. Skipping...
# Processing Record 319 of Set 1| langenfeld
# Processing Record 320 of Set 1| dzaoudzi
# Processing Record 321 of Set 1| coari
# Processing Record 322 of Set 1| silver city
# Processing Record 323 of Set 1| yulara
# City not found. Skipping...
# Processing Record 324 of Set 1| saint-georges
# Processing Record 325 of Set 1| riberalta
# Processing Record 326 of Set 1| waipawa
# Processing Record 327 of Set 1| bang rakam
# Processing Record 328 of Set 1| camacha
# Processing Record 329 of Set 1| ajaccio
# Processing Record 330 of Set 1| maldonado
# Processing Record 331 of Set 1| cacoal
# Processing Record 332 of Set 1| seymchan
# Processing Record 333 of Set 1| temple
# Processing Record 334 of Set 1| mahuta
# Processing Record 335 of Set 1| katobu
# Processing Record 336 of Set 1| roma
# Processing Record 337 of Set 1| bato
# Processing Record 338 of Set 1| umm lajj
# Processing Record 339 of Set 1| naze
# Processing Record 340 of Set 1| huarmey
# Processing Record 341 of Set 1| vila franca do campo
# Processing Record 342 of Set 1| yakima
# Processing Record 343 of Set 1| kantabanji
# Processing Record 344 of Set 1| asau
# Processing Record 345 of Set 1| homer
# Processing Record 346 of Set 1| shimoda
# Processing Record 347 of Set 1| sisimiut
# Processing Record 348 of Set 1| shimanovsk
# Processing Record 349 of Set 1| poum
# Processing Record 350 of Set 1| saint-francois
# Processing Record 351 of Set 1| ciudad valles
# City not found. Skipping...
# Processing Record 352 of Set 1| prince rupert
# Processing Record 353 of Set 1| ixtapa
# Processing Record 354 of Set 1| hohhot
# Processing Record 355 of Set 1| mount gambier
# Processing Record 356 of Set 1| vardo
# Processing Record 357 of Set 1| mazagao
# Processing Record 358 of Set 1| kieta
# Processing Record 359 of Set 1| vostok
# Processing Record 360 of Set 1| balkanabat
# Processing Record 361 of Set 1| aswan
# Processing Record 362 of Set 1| goya
# City not found. Skipping...
# Processing Record 363 of Set 1| yarada
# Processing Record 364 of Set 1| ribeira grande
# Processing Record 365 of Set 1| adigeni
# Processing Record 366 of Set 1| port moresby
# Processing Record 367 of Set 1| sambava
# Processing Record 368 of Set 1| panama city
# Processing Record 369 of Set 1| ballina
# Processing Record 370 of Set 1| estelle
# Processing Record 371 of Set 1| huilong
# Processing Record 372 of Set 1| petropavlovsk-kamchatskiy
# Processing Record 373 of Set 1| westport
# Processing Record 374 of Set 1| ekhabi
# Processing Record 375 of Set 1| salisbury
# Processing Record 376 of Set 1| phonhong
# Processing Record 377 of Set 1| galdar
# Processing Record 378 of Set 1| tahoua
# Processing Record 379 of Set 1| neuquen
# Processing Record 380 of Set 1| granadilla de abona
# Processing Record 381 of Set 1| sistranda
# Processing Record 382 of Set 1| ariquemes
# Processing Record 383 of Set 1| kloulklubed
# Processing Record 384 of Set 1| iquitos
# Processing Record 385 of Set 1| dalbandin
# Processing Record 386 of Set 1| ust-kuyga
# Processing Record 387 of Set 1| carballo
# Processing Record 388 of Set 1| berdigestyakh
# Processing Record 389 of Set 1| nelson bay
# Processing Record 390 of Set 1| kalaleh
# Processing Record 391 of Set 1| tuatapere
# Processing Record 392 of Set 1| barra do garcas
# Processing Record 393 of Set 1| karatau
# Processing Record 394 of Set 1| omsukchan
# Processing Record 395 of Set 1| floro
# Processing Record 396 of Set 1| polunochnoye
# Processing Record 397 of Set 1| klaksvik
# Processing Record 398 of Set 1| ambilobe
# City not found. Skipping...
# Processing Record 399 of Set 1| barsovo
# Processing Record 400 of Set 1| kasama
# Processing Record 401 of Set 1| tuy hoa
# Processing Record 402 of Set 1| okhotsk
# Processing Record 403 of Set 1| jeremie
# Processing Record 404 of Set 1| monforte de lemos
# Processing Record 405 of Set 1| hamilton
# Processing Record 406 of Set 1| bayir
# Processing Record 407 of Set 1| ostrovnoy
# Processing Record 408 of Set 1| dzhankoy
# Processing Record 409 of Set 1| warragul
# Processing Record 410 of Set 1| ancud
# Processing Record 411 of Set 1| mandan
# Processing Record 412 of Set 1| coahuayana
# Processing Record 413 of Set 1| chernyshevskiy
# Processing Record 414 of Set 1| nanlong
# Processing Record 415 of Set 1| batemans bay
# Processing Record 416 of Set 1| atambua
# Processing Record 417 of Set 1| lincoln
# Processing Record 418 of Set 1| victoria point
# Processing Record 419 of Set 1| goderich
# Processing Record 420 of Set 1| graaff-reinet
# City not found. Skipping...
# Processing Record 421 of Set 1| nova olimpia
# Processing Record 422 of Set 1| padilla
# Processing Record 423 of Set 1| macklin
# Processing Record 424 of Set 1| tawang
# Processing Record 425 of Set 1| medzilaborce
# Processing Record 426 of Set 1| lewistown
# Processing Record 427 of Set 1| caldwell
# Processing Record 428 of Set 1| dourbali
# Processing Record 429 of Set 1| progreso
# Processing Record 430 of Set 1| ankazoabo
# Processing Record 431 of Set 1| vega de alatorre
# Processing Record 432 of Set 1| hambantota
# Processing Record 433 of Set 1| champasak
# Processing Record 434 of Set 1| bilma
# Processing Record 435 of Set 1| kushmurun
# Processing Record 436 of Set 1| casper
# Processing Record 437 of Set 1| nizhniy odes
# Processing Record 438 of Set 1| ziniare
# Processing Record 439 of Set 1| nome
# Processing Record 440 of Set 1| aktas
# Processing Record 441 of Set 1| canavieiras
# City not found. Skipping...
# Processing Record 442 of Set 1| christchurch
# Processing Record 443 of Set 1| dongsheng
# Processing Record 444 of Set 1| harper
# Processing Record 445 of Set 1| saint-pierre
# Processing Record 446 of Set 1| rio grande
# Processing Record 447 of Set 1| henties bay
# Processing Record 448 of Set 1| hanzhong
# Processing Record 449 of Set 1| stutterheim
# Processing Record 450 of Set 1| limon
# Processing Record 451 of Set 1| ano mera
# Processing Record 452 of Set 1| hokitika
# Processing Record 453 of Set 1| navrongo
# Processing Record 454 of Set 1| makakilo city
# Processing Record 455 of Set 1| aviles
# Processing Record 456 of Set 1| cehegin
# Processing Record 457 of Set 1| dunedin
# Processing Record 458 of Set 1| carutapera
# Processing Record 459 of Set 1| sobolevo
# Processing Record 460 of Set 1| jumla
# Processing Record 461 of Set 1| sao felix do xingu
# Processing Record 462 of Set 1| almeirim
# Processing Record 463 of Set 1| jiazi
# Processing Record 464 of Set 1| tongren
# Processing Record 465 of Set 1| linxia
# Processing Record 466 of Set 1| balakhta
# Processing Record 467 of Set 1| husavik
# Processing Record 468 of Set 1| zelenets
# Processing Record 469 of Set 1| maloy
# Processing Record 470 of Set 1| wewak
# Processing Record 471 of Set 1| puerto del rosario
# Processing Record 472 of Set 1| pangnirtung
# Processing Record 473 of Set 1| souillac
# Processing Record 474 of Set 1| bandarbeyla
# Processing Record 475 of Set 1| college
# Processing Record 476 of Set 1| bathsheba
# Processing Record 477 of Set 1| morondava
# Processing Record 478 of Set 1| denpasar
# Processing Record 479 of Set 1| kahama
# Processing Record 480 of Set 1| hofn
# Processing Record 481 of Set 1| chlorakas
# City not found. Skipping...
# Processing Record 482 of Set 1| georgiyevka
# Processing Record 483 of Set 1| ferrol
# Processing Record 484 of Set 1| san francisco
# Processing Record 485 of Set 1| viedma
# Processing Record 486 of Set 1| beaumont
# Processing Record 487 of Set 1| winchester
# City not found. Skipping...
# Processing Record 488 of Set 1| abu samrah
# Processing Record 489 of Set 1| itamaraju
# Processing Record 490 of Set 1| yumen
# Processing Record 491 of Set 1| phan thiet
# Processing Record 492 of Set 1| belyy yar
# Processing Record 493 of Set 1| rybinsk
# Processing Record 494 of Set 1| wembley
# Processing Record 495 of Set 1| valparaiso
# Processing Record 496 of Set 1| beloha
# Processing Record 497 of Set 1| ponerihouen
# Processing Record 498 of Set 1| byron bay
# Processing Record 499 of Set 1| lethem
# Processing Record 500 of Set 1| itinga
# Processing Record 501 of Set 1| natal
# Processing Record 502 of Set 1| sarakhs
# City not found. Skipping...
# Processing Record 503 of Set 1| mumford
# Processing Record 504 of Set 1| alta
# Processing Record 505 of Set 1| ewa beach
# Processing Record 506 of Set 1| ketchikan
# Processing Record 507 of Set 1| zharkent
# Processing Record 508 of Set 1| walvis bay
# Processing Record 509 of Set 1| catamarca
# Processing Record 510 of Set 1| cimarron hills
# Processing Record 511 of Set 1| komsomolskiy
# Processing Record 512 of Set 1| tacuati
# Processing Record 513 of Set 1| moindou
# Processing Record 514 of Set 1| ghatsila
# Processing Record 515 of Set 1| dovers
# Processing Record 516 of Set 1| el dorado
# Processing Record 517 of Set 1| margate
# Processing Record 518 of Set 1| tabuk
# Processing Record 519 of Set 1| mayna
# City not found. Skipping...
# Processing Record 520 of Set 1| shirokiy
# Processing Record 521 of Set 1| digby
# City not found. Skipping...
# Processing Record 522 of Set 1| junction city
# Processing Record 523 of Set 1| gualeguay
# Processing Record 524 of Set 1| pacific grove
# Processing Record 525 of Set 1| japura
# Processing Record 526 of Set 1| shakawe
# Processing Record 527 of Set 1| candolim
# Processing Record 528 of Set 1| igarka
# Processing Record 529 of Set 1| mackay
# Processing Record 530 of Set 1| aqtobe
# Processing Record 531 of Set 1| dunmore east
# Processing Record 532 of Set 1| ous
# Processing Record 533 of Set 1| port augusta
# Processing Record 534 of Set 1| sumbe
# Processing Record 535 of Set 1| sorada
# Processing Record 536 of Set 1| paducah
# Processing Record 537 of Set 1| kota tinggi
# City not found. Skipping...
# Processing Record 538 of Set 1| tyup
# Processing Record 539 of Set 1| la paz
# Processing Record 540 of Set 1| bahia honda
# Processing Record 541 of Set 1| port-cartier
# Processing Record 542 of Set 1| sorong
# Processing Record 543 of Set 1| mitsamiouli
# Processing Record 544 of Set 1| talcahuano
# City not found. Skipping...
# Processing Record 545 of Set 1| gornyak
# Processing Record 546 of Set 1| alizai
# Processing Record 547 of Set 1| finschhafen
# Processing Record 548 of Set 1| san carlos de bariloche
# Processing Record 549 of Set 1| chabahar
# Processing Record 550 of Set 1| caramay
# Processing Record 551 of Set 1| manta
# Processing Record 552 of Set 1| kamenka
# Processing Record 553 of Set 1| breytovo
# Processing Record 554 of Set 1| galiakot
# City not found. Skipping...
# Processing Record 555 of Set 1| bezhanitsy
# Processing Record 556 of Set 1| port macquarie
# City not found. Skipping...
# Processing Record 557 of Set 1| iranshahr
# Processing Record 558 of Set 1| sibolga
# Processing Record 559 of Set 1| ocosingo
# Processing Record 560 of Set 1| lucea
# Processing Record 561 of Set 1| starosubkhangulovo

# %%
#Create DataFrame
data = pd.DataFrame(weather_dict)
data.head()
# Out:
#           City Country        Date     Lng    Lat  Max Temp  Cloudiness  \
# 0     Galesong      ID  1586483419  119.37  -5.32     30.00          20
# 1      Malanje      AO  1586483421   16.34  -9.54     18.17         100
# 2    Saskylakh      RU  1586483422  114.08  71.92     -3.47           3
# 3    Busselton      AU  1586483423  115.33 -33.65     25.00         100
# 4  Broken Hill      AU  1586483424  141.43 -31.95     21.00           0
#
#    Humidity  Wind Speed
# 0        79        1.00
# 1        71        1.31
# 2        92        8.72
# 3        46        4.20
# 4        43        5.70

# %%
#Check and Save Data as CSV
data.count()
data.to_csv("Places Data.csv", index=False, header=True)
data.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>Country</th>\n      <th>Date</th>\n      <th>Lng</th>\n      <th>Lat</th>\n      <th>Max Temp</th>\n      <th>Cloudiness</th>\n      <th>Humidity</th>\n      <th>Wind Speed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Galesong</td>\n      <td>ID</td>\n      <td>1586483419</td>\n      <td>119.37</td>\n      <td>-5.32</td>\n      <td>30.00</td>\n      <td>20</td>\n      <td>79</td>\n      <td>1.00</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Malanje</td>\n      <td>AO</td>\n      <td>1586483421</td>\n      <td>16.34</td>\n      <td>-9.54</td>\n      <td>18.17</td>\n      <td>100</td>\n      <td>71</td>\n      <td>1.31</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Saskylakh</td>\n      <td>RU</td>\n      <td>1586483422</td>\n      <td>114.08</td>\n      <td>71.92</td>\n      <td>-3.47</td>\n      <td>3</td>\n      <td>92</td>\n      <td>8.72</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Busselton</td>\n      <td>AU</td>\n      <td>1586483423</td>\n      <td>115.33</td>\n      <td>-33.65</td>\n      <td>25.00</td>\n      <td>100</td>\n      <td>46</td>\n      <td>4.20</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Broken Hill</td>\n      <td>AU</td>\n      <td>1586483424</td>\n      <td>141.43</td>\n      <td>-31.95</td>\n      <td>21.00</td>\n      <td>0</td>\n      <td>43</td>\n      <td>5.70</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Oktyabrskoye</td>\n      <td>RU</td>\n      <td>1586483426</td>\n      <td>44.74</td>\n      <td>43.06</td>\n      <td>3.81</td>\n      <td>0</td>\n      <td>55</td>\n      <td>0.67</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>Abu Dhabi</td>\n      <td>AE</td>\n      <td>1586483293</td>\n      <td>54.37</td>\n      <td>24.47</td>\n      <td>29.00</td>\n      <td>0</td>\n      <td>30</td>\n      <td>1.50</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>Kodiak</td>\n      <td>US</td>\n      <td>1586483428</td>\n      <td>-152.41</td>\n      <td>57.79</td>\n      <td>6.00</td>\n      <td>1</td>\n      <td>41</td>\n      <td>2.60</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>Antigonish</td>\n      <td>CA</td>\n      <td>1586483429</td>\n      <td>-62.00</td>\n      <td>45.62</td>\n      <td>1.11</td>\n      <td>90</td>\n      <td>93</td>\n      <td>4.60</td>\n    </tr>\n    <tr>\n      <th>9</th>\n      <td>Port Elizabeth</td>\n      <td>ZA</td>\n      <td>1586483431</td>\n      <td>25.57</td>\n      <td>-33.92</td>\n      <td>15.00</td>\n      <td>100</td>\n      <td>87</td>\n      <td>1.00</td>\n    </tr>\n    <tr>\n      <th>10</th>\n      <td>Talnakh</td>\n      <td>RU</td>\n      <td>1586483432</td>\n      <td>88.40</td>\n      <td>69.49</td>\n      <td>-6.00</td>\n      <td>90</td>\n      <td>92</td>\n      <td>16.00</td>\n    </tr>\n    <tr>\n      <th>11</th>\n      <td>Hilo</td>\n      <td>US</td>\n      <td>1586483434</td>\n      <td>-155.09</td>\n      <td>19.73</td>\n      <td>27.00</td>\n      <td>90</td>\n      <td>65</td>\n      <td>4.10</td>\n    </tr>\n    <tr>\n      <th>12</th>\n      <td>Turbiv</td>\n      <td>UA</td>\n      <td>1586483436</td>\n      <td>28.72</td>\n      <td>49.35</td>\n      <td>8.41</td>\n      <td>23</td>\n      <td>65</td>\n      <td>4.92</td>\n    </tr>\n    <tr>\n      <th>13</th>\n      <td>Kihei</td>\n      <td>US</td>\n      <td>1586483437</td>\n      <td>-156.47</td>\n      <td>20.79</td>\n      <td>27.00</td>\n      <td>20</td>\n      <td>65</td>\n      <td>5.70</td>\n    </tr>\n    <tr>\n      <th>14</th>\n      <td>Alofi</td>\n      <td>NU</td>\n      <td>1586483438</td>\n      <td>-169.92</td>\n      <td>-19.06</td>\n      <td>29.00</td>\n      <td>75</td>\n      <td>79</td>\n      <td>4.10</td>\n    </tr>\n    <tr>\n      <th>15</th>\n      <td>Bundaberg</td>\n      <td>AU</td>\n      <td>1586483251</td>\n      < ...

# %%
#Plotting the Data
#Latitude vs. Temperature Plot
plt.scatter(data["Lat"], data["Max Temp"],alpha=0.3)
plt.title("Latitude vs. Temperature Plot")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)
# Save the Figure
plt.savefig("Latitude vs. Temperature Plot.png")
# Show Figure
plt.show()

# %%
#Plotting the Data
#Latitude vs. Humidity Plot
plt.scatter(data["Lat"], data["Humidity"],alpha=0.3)
plt.title("Latitude vs. Humidity Plot")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid(True)
# Save the Figure
plt.savefig("Latitude vs. Humidity Plot.png")
# Show Figure
plt.show()

# %%
#Plotting the Data
#Latitude vs. Cloudiness Plot
plt.scatter(data["Lat"], data["Cloudiness"],alpha=0.3)
plt.title("Latitude vs. Cloudiness Plot")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid(True)
# Save the Figure
plt.savefig("Latitude vs. Cloudiness Plot.png")
# Show Figure
plt.show()

# %%
#Plotting the Data
#Latitude vs. Wind Speed Plot
plt.scatter(data["Lat"], data["Wind Speed"],alpha=0.3)
plt.title("Latitude vs. Wind Speed Plot")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (KT)")
plt.grid(True)
# Save the Figure
plt.savefig("Latitude vs. Wind Speed Plot.png")
# Show Figure
plt.show()
